# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="")#enter youre api key from roboflow
project = rf.workspace("ailaba1").project("laba1-w6wnj")
version = project.version(7)
dataset = version.download("yolov7")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 13.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 33.6 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   Attempting uninstall: certifi
# ...

# %%
#looks good
rf = Roboflow(api_key="")#enter youre api key from roboflow
project = rf.workspace("test-sqseu").project("gender-ywbvh")
version = project.version(5)
dataset = version.download("yolov7")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Gender-5 in yolov7pytorch:: 100%|██████████| 3366/3366 [00:00<00:00, 7158.72it/s]

# %%
#arab
rf = Roboflow(api_key="")#enter youre api key from roboflow
project = rf.workspace("new-workspace-15ant").project("gender-description-2")
version = project.version(1)
dataset = version.download("yolov7")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to gender-description-2-1 in yolov7pytorch:: 100%|██████████| 722/722 [00:00<00:00, 8643.93it/s]

# %%
rf = Roboflow(api_key="")#enter youre api key from roboflow
project = rf.workspace("lynkeus09-zcpqi").project("male-female-kmmoa")
version = project.version(2)
dataset = version.download("yolov7")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to male-female-2 in yolov7pytorch:: 100%|██████████| 2575/2575 [00:00<00:00, 4363.36it/s]

# %%
# !git clone https://github.com/WongKinYiu/yolov7.git
# Out:
# Cloning into 'yolov7'...
# remote: Enumerating objects: 1197, done.
# remote: Total 1197 (delta 0), reused 0 (delta 0), pack-reused 1197
# Receiving objects: 100% (1197/1197), 74.23 MiB | 33.44 MiB/s, done.
# Resolving deltas: 100% (519/519), done.

# %%
# !cp -r /kaggle/input/yolov7Custom.yaml /kaggle/working/yolov7/cfg/training
# !cp -r /kaggle/input/custom_data.yaml /kaggle/working/yolov7/data

# %%
#main data train & validation
# !cp -r /kaggle/working/laba1-7/train /kaggle/working/yolov7/data
# !cp -r /kaggle/working/laba1-7/valid /kaggle/working/yolov7/data

# %%
#second data train
# !cp -r /kaggle/working/male-female-2/train/labels/. /kaggle/working/yolov7/data/train/labels
# !cp -r /kaggle/working/male-female-2/train/images/. /kaggle/working/yolov7/data/train/images
#second data valid
# !cp -r /kaggle/working/male-female-2/valid/labels/. /kaggle/working/yolov7/data/valid/labels
# !cp -r /kaggle/working/male-female-2/valid/images/. /kaggle/working/yolov7/data/valid/images

# %%
#third data train
# !cp -r /kaggle/working/gender-description-2-1/train/labels/. /kaggle/working/yolov7/data/train/labels
# !cp -r /kaggle/working/gender-description-2-1/train/images/. /kaggle/working/yolov7/data/train/images
#third data valid
# !cp -r /kaggle/working/gender-description-2-1/valid/labels/. /kaggle/working/yolov7/data/valid/labels
# !cp -r /kaggle/working/gender-description-2-1/valid/images/. /kaggle/working/yolov7/data/valid/images

# %%
#fourth data train
# !cp -r /kaggle/working/Gender-5/train/labels/. /kaggle/working/yolov7/data/train/labels
# !cp -r /kaggle/working/Gender-5/train/images/. /kaggle/working/yolov7/data/train/images
#fourth data valid
# !cp -r /kaggle/working/Gender-5/valid/labels/. /kaggle/working/yolov7/data/valid/labels
# !cp -r /kaggle/working/Gender-5/valid/images/. /kaggle/working/yolov7/data/valid/images

# %%
#counting train samples
ls /kaggle/working/yolov7/data/train/labels | grep ".txt" -c
# Out:
# 4371

# %%
#counting validation samples
ls /kaggle/working/yolov7/data/valid/labels | grep ".txt" -c
# Out:
# 571

# %%
#changing dir to yolo
cd /kaggle/working/yolov7
# Out:
# /kaggle/working/yolov7

# %%
#training yolov7 without waandb 
# !WANDB_MODE="dryrun" python train.py --device 0 --batch-size 24 --epochs 68 --img 640 640 --data data/custom_data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7Custom.yaml --weights yolov7.pt --name yolov7-custom
# Out:
# 2024-03-29 14:04:22.170363: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-29 14:04:22.170486: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-29 14:04:22.307146: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: WARNING `resume` will be ignored since W&B syncing is set to `offline`. Starting a new run with run id pjznl1bf.
# wandb: Tracking run with wandb version 0.16.4
# wandb: W&B syncing is set to `offline` in this directory.
# wandb: Run `wandb online` or set WANDB_MODE=online to enable cloud syncing.
# ...

# %%
#copressing best weights to downloade 
# %cd /kaggle/working/
# !zip -r model_all.zip /kaggle/working/yolov7/runs/train/yolov7-custom/weights/best.pt
# Out:
# /kaggle/working
#   adding: kaggle/working/yolov7/runs/train/yolov7-custom/weights/best.pt (deflated 8%)

# %%
#downloading model
from IPython.display import FileLink

FileLink('model_all.zip')
# Out:
# /kaggle/working/model_all.zip
